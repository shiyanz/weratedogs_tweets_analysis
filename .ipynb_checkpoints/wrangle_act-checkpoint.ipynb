# %% [markdown]
# ## Gather

# %%
import requests
import tweepy
import json
import pandas as pd
import numpy as np

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
r = requests.get(url)
with open('image_predictions.tsv','wb') as file:
    file.write(r.content)

# %%
image_predictions = pd.read_csv('image_predictions.tsv', sep = '\t')
tweet_archive = pd.read_csv('twitter-archive-enhanced.csv')
tweet_ids = tweet_archive.tweet_id.tolist()

# %%
consumer_key = 'nR11zkt7OPiz6XbF61nZaK7Tk'
consumer_secret = 'yuJouFHjiJUIwuV4soVdJB3CDQ1zvKW3st4FhYqnLvdchMuEV5'
access_token = '549397271-Yd1HnXZLs8GO6zlBuImPMeJsNF4jrlZCIwn8uCKk'
access_secret = 'jPHmNJIrkHPoBnTuS8Xs5aidkPTTgftpOjOYBtIBdQRtB'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %% [markdown]
# Each tweet's retweet count and favorite ("like") count at minimum, and any additional data you find interesting. Using the tweet IDs in the WeRateDogs Twitter archive, query the Twitter API for each tweet's JSON data using Python's Tweepy library and store each tweet's entire set of JSON data in a file called tweet_json.txt file. Each tweet's JSON data should be written to its own line. Then read this .txt file line by line into a pandas DataFrame with (at minimum) tweet ID, retweet count, and favorite count. Note: do not include your Twitter API keys, secrets, and tokens in your project submission.

# %%
errors = []
tweets_json = []

for tweet_id in tweet_ids:
    try:  
        tweet = api.get_status(tweet_id, tweet_mode = 'extended')
        tweet_json = json.dumps(tweet._json)
        tweets_json.append(tweet_json)
        with open('tweet_json.txt', mode = 'w', encoding = 'utf-8') as file:
            for tweet_json in tweets_json:
                file.write(tweet_json + '\n')
            
    except Exception as e:
        print(str(tweet_id) + str(e))
        errors.append(str(tweet_id))
    print(tweet_id)
# Out:
# 892420643555336193
# 892177421306343426
# 891815181378084864
# 891689557279858688
# 891327558926688256
# 891087950875897856
# 890971913173991426
# 890729181411237888
# 890609185150312448
# 890240255349198849
# 890006608113172480
# 889880896479866881
# 889665388333682689
# 889638837579907072
# 889531135344209921
# 889278841981685760
# 888917238123831296
# 888804989199671297
# 888554962724278272
# 888202515573088257[{'code': 144, 'message': 'No status found with that ID.'}]
# 888202515573088257
# 888078434458587136
# 887705289381826560
# 887517139158093824
# 887473957103951883
# 887343217045368832
# 887101392804085760
# 886983233522544640
# 886736880519319552
# 886680336477933568
# 886366144734445568
# 886267009285017600
# 886258384151887873
# 886054160059072513
# 885984800019947520
# 885528943205470208
# 885518971528720385
# 885311592912609280
# 885167619883638784
# 884925521741709313
# 884876753390489601
# 884562892145688576
# 884441805382717440
# 884247878851493888
# ...

# %%
tweet_data = []
for line in open('tweet_json.txt','r',encoding = 'utf-8'):
    tweet_data.append(json.loads(line))

# %%
df_list = []
for tweet_dict in tweet_data:
    tweet_id = tweet_dict['id']
    retweet_count = int(tweet_dict['retweet_count'])
    favorite_count = int(tweet_dict['favorite_count'])
    df_list.append({'tweet_id': tweet_id,
                    'retweet_count': retweet_count,
                    'favorite_count': favorite_count})

# %%
tweet_info = pd.DataFrame(df_list, columns = ['tweet_id','retweet_count','favorite_count'])
tweet_info = tweet_info.reset_index(drop=True)

# %%
tweet_errors = pd.DataFrame(errors,columns=['tweet_id'])
tweet_errors
# Out:
#               tweet_id
# 0   888202515573088257
# 1   873697596434513921
# 2   869988702071779329
# 3   866816280283807744
# 4   861769973181624320
# 5   842892208864923648
# 6   837012587749474308
# 7   827228250799742977
# 8   802247111496568832
# 9   775096608509886464
# 10  691675652215414786

# %% [markdown]
# ## Assess

# %%
tweet_info
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           8676           39061
# 1     892177421306343426           6373           33460
# 2     891815181378084864           4233           25217
# 3     891689557279858688           8780           42432
# 4     891327558926688256           9559           40589
# 5     891087950875897856           3172           20358
# 6     890971913173991426           2113           11935
# 7     890729181411237888          19230           66032
# 8     890609185150312448           4331           27952
# 9     890240255349198849           7555           32169
# 10    890006608113172480           7460           30847
# 11    889880896479866881           5049           27974
# 12    889665388333682689          10239           48372
# 13    889638837579907072           4622           27372
# 14    889531135344209921           2267           15202
# 15    889278841981685760           5535           25462
# ...

# %%
tweet_archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
image_predictions
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %%
tweet_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2345 entries, 0 to 2344
# Data columns (total 3 columns):
# tweet_id          2345 non-null int64
# retweet_count     2345 non-null int64
# favorite_count    2345 non-null int64
# dtypes: int64(3)
# memory usage: 55.0 KB

# %%
tweet_info.tweet_id.duplicated().sum()
# Out:
# 0

# %%
tweet_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
tweet_archive.rating_numerator.describe()
# Out:
# count    2356.000000
# mean       13.126486
# std        45.876648
# min         0.000000
# 25%        10.000000
# 50%        11.000000
# 75%        12.000000
# max      1776.000000
# Name: rating_numerator, dtype: float64

# %%
tweet_archive[tweet_archive.rating_numerator < 10][['tweet_id','text','rating_numerator']]
# Out:
#                 tweet_id  \
# 45    883482846933004288
# 229   848212111729840128
# 315   835152434251116546
# 387   826598799820865537
# 462   817502432452313088
# 485   814578408554463233
# 599   798682547630837760
# 605   798576900688019456
# 730   781661882474196992
# 745   780092040432480260
# 764   777953400541634568
# 765   777885040357281792
# 784   775096608509886464
# 814   771014301343748096
# 835   768193404517830656
# 845   766423258543644672
# 859   763183847194451968
# 860   763167063695355904
# 883   760252756032651264
# 896   759099523532779520
# 906   758041019896193024
# 912   757596066325864448
# 915   757354760399941633
# 936   753375668877008896
# 946   752568224206688256
# 948   752334515931054080
# 956   751583847268179968
# 964   750506206503038976
# 966   750383411068534784
# 987   749036806121881602
# ...                  ...
# 2312  666776908487630848
# 2314  666701168228331520
# 2315  666691418707132416
# 2316  666649482315059201
# ...

# %%
tweet_archive[tweet_archive.rating_numerator == 1][['tweet_id','text','rating_numerator']]
# Out:
#                 tweet_id  \
# 605   798576900688019456
# 1446  696490539101908992
# 1869  675153376133427200
# 1940  673716320723169284
# 2038  671550332464455680
# 2091  670783437142401025
# 2261  667549055577362432
# 2335  666287406224695296
# 2338  666104133288665088
#
#                                                                                                                                               text  \
# 605   RT @dog_rates: Not familiar with this breed. No tail (weird). Only 2 legs. Doesn't bark. Surprisingly quick. Shits eggs. 1/10 https://t.co/…
# 1446  After reading the comments I may have overestimated this pup. Downgraded to a 1/10. Please forgive me
# 1869  What kind of person sends in a picture without a dog in it? 1/10 just because that's a nice table https://t.co/RDXCfk8hK0
# 1940  The millennials have spoken and we've decided to immediately demote to a 1/10. Thank you
# ...

# %%
tweet_archive[tweet_archive.rating_numerator == 2][['tweet_id','text','rating_numerator']]
# Out:
#                 tweet_id  \
# 1761  678675843183484930
# 1764  678424312106393600
# 1920  674265582246694913
# 2079  670826280409919488
# 2237  668142349051129856
# 2246  667878741721415682
# 2310  666786068205871104
# 2326  666411507551481857
# 2349  666051853826850816
#
#                                                                                                                                               text  \
# 1761  Exotic pup here. Tail long af. Throat looks swollen. Might breathe fire. Exceptionally unfluffy 2/10 would still pet https://t.co/a8SqCaSo2r
# 1764  This is Crystal. She's a shitty fireman. No sense of urgency. People could be dying Crystal. 2/10 just irresponsible https://t.co/rtMtjSl9pz
# 1920  This is Henry. He's a shit dog. Short pointy ears. Leaves trail of pee. Not fluffy. Doesn't come when called. 2/10 https://t.co/Pu9RhfHDEQ
# ...

# %%
tweet_archive[tweet_archive.rating_numerator == 5][['tweet_id','text','rating_numerator']]
# Out:
#                 tweet_id  \
# 45    883482846933004288
# 730   781661882474196992
# 956   751583847268179968
# 1399  699691744225525762
# 1461  694925794720792577
# 1508  691483041324204033
# 1583  687102708889812993
# 1618  684969860808454144
# 1619  684959798585110529
# 1624  684880619965411328
# 1645  683849932751646720
# 1680  682003177596559360
# 1689  681340665377193984
# 1727  679877062409191424
# 1796  677301033169788928
# 1808  676897532954456065
# 1820  676588346097852417
# 1861  675483430902214656
# 1874  675135153782571009
# 1901  674646392044941312
# 1904  674632714662858753
# 1925  674063288070742018
# 1979  672980819271634944
# 2013  672231046314901505
# 2026  671879137494245376
# 2063  671159727754231808
# 2092  670782429121134593
# 2109  670449342516494336
# 2134  670069087419133954
# 2139  670037189829525505
# 2153  669661792646373376
# 2181  668994913074286592
# 2206  668631377374486528
# 2242  667911425562669056
# 2260  667550882905632768
# ...

# %%
tweet_archive[tweet_archive.rating_numerator > 15][['tweet_id','text','rating_numerator']]
# Out:
#                 tweet_id  \
# 55    881633300179243008
# 188   855862651834028034
# 189   855860136149123072
# 290   838150277551247360
# 313   835246439529840640
# 340   832215909146226688
# 433   820690176645140481
# 516   810984652412424192
# 695   786709082849828864
# 763   778027034220126208
# 902   758467244762497024
# 979   749981277374128128
# 1120  731156023742988288
# 1202  716439118184652801
# 1228  713900603437621249
# 1254  710658690886586372
# 1274  709198395643068416
# 1351  704054845121142784
# 1433  697463031882764288
# 1634  684225744407494656
# 1635  684222868335505415
# 1663  682808988178739200
# 1712  680494726643068929
# 1779  677716515794329600
# 1843  675853064436391936
# 2074  670842764863651840
#
#                                                                                                                                                                            text  \
# ...

# %%
tweet_archive.rating_denominator.describe()
# Out:
# count    2356.000000
# mean       10.455433
# std         6.745237
# min         0.000000
# 25%        10.000000
# 50%        10.000000
# 75%        10.000000
# max       170.000000
# Name: rating_denominator, dtype: float64

# %%
tweet_archive[tweet_archive.rating_denominator != 10][['tweet_id','text','rating_numerator','rating_denominator']]
# Out:
#                 tweet_id  \
# 313   835246439529840640
# 342   832088576586297345
# 433   820690176645140481
# 516   810984652412424192
# 784   775096608509886464
# 902   758467244762497024
# 1068  740373189193256964
# 1120  731156023742988288
# 1165  722974582966214656
# 1202  716439118184652801
# 1228  713900603437621249
# 1254  710658690886586372
# 1274  709198395643068416
# 1351  704054845121142784
# 1433  697463031882764288
# 1598  686035780142297088
# 1634  684225744407494656
# 1635  684222868335505415
# 1662  682962037429899265
# 1663  682808988178739200
# 1779  677716515794329600
# 1843  675853064436391936
# 2335  666287406224695296
#
#                                                                                                                                                                            text  \
# 313   @jonnysun @Lin_Manuel ok jomny I know you're excited but 960/00 isn't a valid rating, 13/10 is tho
# 342   @docmisterio account started on 11/15/15
# ...

# %%
tweet_archive.tweet_id.duplicated().sum()
# Out:
# 0

# %%
tweet_archive.name.value_counts()
# Out:
# None          745
# a              55
# Charlie        12
# Oliver         11
# Lucy           11
# Cooper         11
# Tucker         10
# Penny          10
# Lola           10
# Winston         9
# Bo              9
# Sadie           8
# the             8
# Toby            7
# Daisy           7
# Buddy           7
# an              7
# Bailey          7
# Leo             6
# Bella           6
# Jack            6
# Stanley         6
# Milo            6
# Scout           6
# Rusty           6
# Koda            6
# Oscar           6
# Dave            6
# Jax             6
# Gus             5
#              ...
# Buddah          1
# Hubertson       1
# Randall         1
# Ole             1
# Norman          1
# Travis          1
# Rodman          1
# Dutch           1
# DayZ            1
# Akumi           1
# Kramer          1
# Tove            1
# Tug             1
# Jareld          1
# Christoper      1
# all             1
# Fido            1
# Sonny           1
# Rufio           1
# ...

# %%
tweet_archive[~tweet_archive.name.str.contains(r'[A-Z]')].name.value_counts()
# Out:
# a               55
# the              8
# an               7
# very             5
# just             4
# quite            4
# one              4
# getting          2
# actually         2
# not              2
# mad              2
# all              1
# space            1
# incredibly       1
# unacceptable     1
# life             1
# light            1
# by               1
# such             1
# officially       1
# infuriating      1
# this             1
# his              1
# my               1
# old              1
# Name: name, dtype: int64

# %%
image_predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
image_predictions.p1_conf.sort_values()
# Out:
# 38      0.044333
# 136     0.055379
# 1093    0.059033
# 1370    0.063152
# 246     0.070076
# 250     0.071124
# 145     0.071536
# 680     0.072885
# 701     0.081101
# 1831    0.082489
# 18      0.086502
# 109     0.088530
# 568     0.088540
# 301     0.089165
# 1627    0.090341
# 1503    0.090341
# 954     0.090508
# 277     0.096063
# 2074    0.097049
# 664     0.097232
# 789     0.097500
# 515     0.098283
# 1664    0.099804
# 731     0.100499
# 1723    0.100896
# 1037    0.105171
# 247     0.107317
# 876     0.107948
# 866     0.110587
# 1245    0.111493
#           ...
# 76      0.999091
# 1988    0.999120
# 2045    0.999201
# 863     0.999223
# 1872    0.999281
# 1548    0.999306
# 95      0.999335
# 611     0.999365
# 1711    0.999403
# 512     0.999484
# 168     0.999614
# 107     0.999647
# 1796    0.999715
# 1455    0.999823
# 1687    0.999828
# 1725    0.999833
# 331     0.999834
# 1014    0.999837
# 594     0.999846
# 475     0.999876
# 865     0.999885
# ...

# %%
all_columns = pd.Series(list(tweet_info) + list(tweet_archive) + list(image_predictions))
all_columns[all_columns.duplicated()]
# Out:
# 3     tweet_id
# 20    tweet_id
# dtype: object

# %% [markdown]
# #### Quality
# - `tweet_id` 666287406224695296 should have a rating of 9/10 instead of 1/2.
# `tweet_id` 881633300179243008 should have a rating of 14 instead of 17.
# `tweet_id` 786709082849828864 and 832215909146226688 should have a rating of 9.75 instead of 75.
# `tweet_id` 778027034220126208 should have a rating of 11.27 instead of 27.
# `tweet_id` 716439118184652801 should be rated 11/10 instead of 50/50.
# `tweet_id` 680494726643068929 should rate 11.26 instead of 26.
# `tweet_id` 835246439529840640 should rate 13/10.
# `tweet_id` 810984652412424192 doesn't have a rating.
# `tweet_id` 832088576586297345 is not a dog rating tweet.
# `tweet_id` 775096608509886464 and 740373189193256964 have the same content and should be rated rated 14/10.
# `tweet_id` 722974582966214656 should be rated 13/10.
# `tweet_id` 682962037429899265 should be rated 10/10 instead of 7/11.
# `tweet_id` 682808988178739200 is not a rating.
# `tweet_id` 686035780142297088 is not a rating.
# `tweet_id` 681340665377193984 should be rated 9.5 instead of 5.
# `tweet_id` 883482846933004288 should be rated 13.5 instead of 5.
# - Some dog names are recorded as "None", 'a', 'an', 'quite', 'the', and 'such', etc.
# - `timestamp` and `retweeted_status_timestamp` are strings not datetime datatypes.
# - `img_num` is an integer not a category.
# - Some tweets are retweets.
# - Some tweets don't have images (2075 pictures in `image_predictions` table out of 2356 tweet_ids in the `tweet_archive` table).
# - Some of the predictions in `p1`, `p2` and `p3` columns start with uppercase letters and others with lowercases.
# - Some column names in the `impage_predictions` table are not descriptive (`p1_conf`, `p1_dog`, etc.)
#
# #### Tidiness
# - One variable `dog_stage` is saved in four columns (from `doggo` to `puppo`).
# - `tweet_info` table and `tweet_archive` table should be one table.

# %% [markdown]
# ## Clean

# %%
info_clean = tweet_info.copy()
archive_clean = tweet_archive.copy()
predictions_clean = image_predictions.copy()

# %% [markdown]
# ### Missing Data

# %% [markdown]
# **Some tweets don't have images (2075 pictures in `image_predictions` table out of 2356 tweet_ids in the `tweet_archive` table).**

# %% [markdown]
# ##### Define
# Isolate the `tweet_id` column in the `image_predications` table and join it with `tweet_archive`.

# %% [markdown]
# ##### Code

# %%
ids = predictions_clean[['tweet_id']]
archive_clean = pd.merge(ids, archive_clean, on=['tweet_id'], how='left')

# %% [markdown]
# ##### Test

# %%
archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2074
# Data columns (total 17 columns):
# tweet_id                      2075 non-null int64
# in_reply_to_status_id         23 non-null float64
# in_reply_to_user_id           23 non-null float64
# timestamp                     2075 non-null object
# source                        2075 non-null object
# text                          2075 non-null object
# retweeted_status_id           81 non-null float64
# retweeted_status_user_id      81 non-null float64
# retweeted_status_timestamp    81 non-null object
# expanded_urls                 2075 non-null object
# rating_numerator              2075 non-null int64
# rating_denominator            2075 non-null int64
# name                          2075 non-null object
# doggo                         2075 non-null object
# floofer                       2075 non-null object
# pupper                        2075 non-null object
# ...

# %%
archive_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  666020888022790149 NaN                    NaN
# 1  666029285002620928 NaN                    NaN
# 2  666033412701032449 NaN                    NaN
# 3  666044226329800704 NaN                    NaN
# 4  666049248165822465 NaN                    NaN
#
#                    timestamp  \
# 0  2015-11-15 22:32:08 +0000
# 1  2015-11-15 23:05:30 +0000
# 2  2015-11-15 23:21:54 +0000
# 3  2015-11-16 00:04:52 +0000
# 4  2015-11-16 00:24:50 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %% [markdown]
# ### Tidiness

# %% [markdown]
# **One variable `dog_stage` is saved in four columns (from `doggo` to `puppo`).**

# %% [markdown]
# ##### Define
# Concatenate the stings in the four stage columns to a `dog_state` column and replace 'None' with the ''. Then drop the original columns.

# %% [markdown]
# ##### Code

# %%
archive_clean['dog_stage'] = archive_clean['doggo']+archive_clean['floofer']+archive_clean['pupper']+archive_clean['puppo']

# %%
archive_clean['dog_stage'] = archive_clean.dog_stage.str.replace('None','')
archive_clean = archive_clean.replace('', np.nan, regex=True)

# %%
archive_clean = archive_clean.drop(['doggo','floofer','pupper','puppo'], axis=1)

# %% [markdown]
# ##### Test

# %%
archive_clean.dog_stage.value_counts()
# Out:
# pupper          211
# doggo           67
# puppo           23
# doggopupper     11
# floofer         7
# doggopuppo      1
# doggofloofer    1
# Name: dog_stage, dtype: int64

# %%
archive_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  666020888022790149 NaN                    NaN
# 1  666029285002620928 NaN                    NaN
# 2  666033412701032449 NaN                    NaN
# 3  666044226329800704 NaN                    NaN
# 4  666049248165822465 NaN                    NaN
#
#                    timestamp  \
# 0  2015-11-15 22:32:08 +0000
# 1  2015-11-15 23:05:30 +0000
# 2  2015-11-15 23:21:54 +0000
# 3  2015-11-16 00:04:52 +0000
# 4  2015-11-16 00:24:50 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %% [markdown]
# **`tweet_info` table and tweet_archive table should be one table.**

# %% [markdown]
# ##### Define
# Merge `tweet_info` and `tweet_archive` by `tweet_id` in `tweet_archive`.

# %% [markdown]
# ##### Code

# %%
archive_clean = pd.merge(archive_clean, info_clean, on='tweet_id', how='left')

# %% [markdown]
# ##### Test

# %%
archive_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  666020888022790149 NaN                    NaN
# 1  666029285002620928 NaN                    NaN
# 2  666033412701032449 NaN                    NaN
# 3  666044226329800704 NaN                    NaN
# 4  666049248165822465 NaN                    NaN
#
#                    timestamp  \
# 0  2015-11-15 22:32:08 +0000
# 1  2015-11-15 23:05:30 +0000
# 2  2015-11-15 23:21:54 +0000
# 3  2015-11-16 00:04:52 +0000
# 4  2015-11-16 00:24:50 +0000
#
#                                                                                source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2074
# Data columns (total 16 columns):
# tweet_id                      2075 non-null int64
# in_reply_to_status_id         23 non-null float64
# in_reply_to_user_id           23 non-null float64
# timestamp                     2075 non-null object
# source                        2075 non-null object
# text                          2075 non-null object
# retweeted_status_id           81 non-null float64
# retweeted_status_user_id      81 non-null float64
# retweeted_status_timestamp    81 non-null object
# expanded_urls                 2075 non-null object
# rating_numerator              2075 non-null int64
# rating_denominator            2075 non-null int64
# name                          2075 non-null object
# dog_stage                     321 non-null object
# retweet_count                 2068 non-null float64
# favorite_count                2068 non-null float64
# dtypes: float64(6), int64(3), object(7)
# ...

# %% [markdown]
# ### Quality

# %% [markdown]
# **Some tweets are retweets.**

# %% [markdown]
# ##### Define
# Select rows in the `archive` table that the `retweeted_status_id` column is null and drop the `retweeted_status_id`, `retweeted_status_user_id` and `retweeted_status_timestamp` columns afterwards. Isolate the `tweet_id` column in the `archive` table and merge with the `predictions` table.

# %% [markdown]
# ##### Code

# %%
archive_clean = archive_clean[archive_clean.retweeted_status_id.isnull()].drop(['retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp'], axis=1)

# %%
new_ids = archive_clean[['tweet_id']]
predictions_clean = pd.merge(new_ids, predictions_clean, on=['tweet_id'], how='left')

# %% [markdown]
# ##### Test

# %%
archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 2074
# Data columns (total 13 columns):
# tweet_id                 1994 non-null int64
# in_reply_to_status_id    23 non-null float64
# in_reply_to_user_id      23 non-null float64
# timestamp                1994 non-null object
# source                   1994 non-null object
# text                     1994 non-null object
# expanded_urls            1994 non-null object
# rating_numerator         1994 non-null int64
# rating_denominator       1994 non-null int64
# name                     1994 non-null object
# dog_stage                306 non-null object
# retweet_count            1993 non-null float64
# favorite_count           1993 non-null float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 218.1+ KB

# %%
predictions_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 1993
# Data columns (total 12 columns):
# tweet_id    1994 non-null int64
# jpg_url     1994 non-null object
# img_num     1994 non-null int64
# p1          1994 non-null object
# p1_conf     1994 non-null float64
# p1_dog      1994 non-null bool
# p2          1994 non-null object
# p2_conf     1994 non-null float64
# p2_dog      1994 non-null bool
# p3          1994 non-null object
# p3_conf     1994 non-null float64
# p3_dog      1994 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 161.6+ KB

# %% [markdown]
# **Erroneous datatypes**
# - **`timestamp` and `retweeted_status_timestamp` are strings not datetime datatypes.**
# - **`img_num` in `image_predictions` is an integer not a category.**

# %% [markdown]
# ##### Define
# Convert `img_num` to a category using `astype`. Convert `timestamp` to a datetime using `to_datetime`.

# %% [markdown]
# ##### Code

# %%
predictions_clean.img_num = predictions_clean.img_num.astype('category')
archive_clean.timestamp = pd.to_datetime(archive_clean.timestamp)

# %% [markdown]
# ##### Test

# %%
archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 2074
# Data columns (total 13 columns):
# tweet_id                 1994 non-null int64
# in_reply_to_status_id    23 non-null float64
# in_reply_to_user_id      23 non-null float64
# timestamp                1994 non-null datetime64[ns]
# source                   1994 non-null object
# text                     1994 non-null object
# expanded_urls            1994 non-null object
# rating_numerator         1994 non-null int64
# rating_denominator       1994 non-null int64
# name                     1994 non-null object
# dog_stage                306 non-null object
# retweet_count            1993 non-null float64
# favorite_count           1993 non-null float64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(5)
# memory usage: 218.1+ KB

# %%
predictions_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 1993
# Data columns (total 12 columns):
# tweet_id    1994 non-null int64
# jpg_url     1994 non-null object
# img_num     1994 non-null category
# p1          1994 non-null object
# p1_conf     1994 non-null float64
# p1_dog      1994 non-null bool
# p2          1994 non-null object
# p2_conf     1994 non-null float64
# p2_dog      1994 non-null bool
# p3          1994 non-null object
# p3_conf     1994 non-null float64
# p3_dog      1994 non-null bool
# dtypes: bool(3), category(1), float64(3), int64(1), object(4)
# memory usage: 148.2+ KB

# %% [markdown]
# **Some dog names are recorded as "None", 'a', 'an', 'quite', 'the', and 'such', etc.**

# %% [markdown]
# ##### Define
# Replace 'None' and values start with lowercase with `np.nan` in the `name` column.

# %% [markdown]
# ##### Code

# %%
other_word_num = archive_clean[~archive_clean.name.str.contains(r'[A-Z]')].name.value_counts().sum()
other_word_num
# Out:
# 98

# %%
None_num = archive_clean[archive_clean.name == 'None'].shape[0]
None_num
# Out:
# 546

# %%
archive_clean.loc[~archive_clean.name.str.contains(r'[A-Z]'),'name'] = np.nan

# %%
archive_clean['name'] = archive_clean.name.replace('None', np.nan, regex=True)

# %% [markdown]
# ##### Test

# %%
archive_clean.name.sample(10)
# Out:
# 499     NaN
# 1800    Kuyu
# 1806    Charlie
# 2066    Zoey
# 259     NaN
# 1756    Pablo
# 308     Reginald
# 934     Charlie
# 687     NaN
# 1774    Sailer
# Name: name, dtype: object

# %%
archive_clean[archive_clean['name'].isnull()].shape[0]
# Out:
# 644

# %%
all_NaN_num = other_word_num + None_num
all_NaN_num
# Out:
# 644

# %% [markdown]
# **`tweet_id` 666287406224695296 should have a rating of 9/10 instead of 1/2.
# `tweet_id` 881633300179243008 should have a rating of 14 instead of 17.
# `tweet_id` 786709082849828864 and 832215909146226688 should have a rating of 9.75 instead of 75.
# `tweet_id` 778027034220126208 should have a rating of 11.27 instead of 27.
# `tweet_id` 716439118184652801 should be rated 11/10 instead of 50/50.
# `tweet_id` 680494726643068929 should rate 11.26 instead of 26.
# `tweet_id` 835246439529840640 should rate 13/10.
# `tweet_id` 810984652412424192 doesn't have a rating.
# `tweet_id` 832088576586297345 is not a dog rating tweet.
# `tweet_id` 775096608509886464 and 740373189193256964 have the same content and should be rated rated 14/10.
# `tweet_id` 722974582966214656 should be rated 13/10.
# `tweet_id` 682962037429899265 should be rated 10/10 instead of 7/11.
# `tweet_id` 682808988178739200 is not a rating.
# `tweet_id` 686035780142297088 is not a rating.
# `tweet_id` 681340665377193984 is not the original tweet but a reply.
# `tweet_id` 883482846933004288 should be rated 13.5 instead of 5.**

# %% [markdown]
# ##### Define
# Some of the tweets above have already be dropped from the `archive_clean` table because they are not original tweets with pictures and ratings.
# Drop the rest of the tweet in the list above that are not original tweets with dog pictures and ratings (810984652412424192).
# Create functions to correct `rating_numerator` and `rating_denominator`.

# %% [markdown]
# ##### Code

# %%
index = archive_clean.index[archive_clean['tweet_id'] == 810984652412424192].tolist()[0]
archive_clean = archive_clean.drop(index, axis = 0)

# %%
def change_rating_numerator(tweet_id, rating):
    archive_clean.loc[archive_clean['tweet_id']==tweet_id,'rating_numerator'] = rating

# %%
change_rating_numerator(666287406224695296, 9)
change_rating_numerator(786709082849828864, 9.75)
change_rating_numerator(778027034220126208, 11.27)
change_rating_numerator(716439118184652801, 11)
change_rating_numerator(680494726643068929, 11.26)
change_rating_numerator(740373189193256964, 14)
change_rating_numerator(722974582966214656, 13)
change_rating_numerator(682962037429899265, 10)
change_rating_numerator(883482846933004288, 13.5)

# %%
def change_rating_denominator(tweet_id, score):
    archive_clean.loc[archive_clean['tweet_id']==tweet_id, 'rating_denominator'] = score

# %%
change_rating_denominator(666287406224695296, 10)
change_rating_denominator(716439118184652801, 10)
change_rating_denominator(740373189193256964, 10)
change_rating_denominator(722974582966214656, 10)
change_rating_denominator(682962037429899265, 10)

# %% [markdown]
# ##### Test

# %%
archive_clean[archive_clean['tweet_id'] == 810984652412424192]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, expanded_urls, rating_numerator, rating_denominator, name, dog_stage, retweet_count, favorite_count]
# Index: []

# %%
archive_clean[archive_clean.rating_denominator != 10][['tweet_id','text','rating_numerator','rating_denominator']]
# Out:
#                 tweet_id  \
# 501   675853064436391936
# 560   677716515794329600
# 692   684222868335505415
# 693   684225744407494656
# 865   697463031882764288
# 941   704054845121142784
# 1007  709198395643068416
# 1025  710658690886586372
# 1050  713900603437621249
# 1148  731156023742988288
# 1338  758467244762497024
# 1728  820690176645140481
#
#                                                                                                                                                     text  \
# 501   Here we have an entire platoon of puppers. Total score: 88/80 would pet all at once https://t.co/y93p6FLvVw
# 560   IT'S PUPPERGEDDON. Total of 144/120 ...I think https://t.co/ZanVtAtvIq
# 692   Someone help the girl is being mugged. Several are distracting her while two steal her shoes. Clever puppers 121/110 https://t.co/1zfnTJLt55
# 693   Two sneaky puppers were not initially seen, moving the rating to 143/130. Please forgive us. Thank you https://t.co/kRK51Y5ac3
# ...

# %%
archive_clean[archive_clean.rating_numerator == 5][['tweet_id','text','rating_numerator','rating_denominator']]
# Out:
#                 tweet_id  \
# 4     666049248165822465
# 43    666776908487630848
# 112   667911425562669056
# 147   668631377374486528
# 171   668994913074286592
# 199   669661792646373376
# 212   670037189829525505
# 217   670069087419133954
# 242   670449342516494336
# 259   670782429121134593
# 288   671159727754231808
# 324   671879137494245376
# 337   672231046314901505
# 371   672980819271634944
# 424   674063288070742018
# 442   674632714662858753
# 445   674646392044941312
# 471   675135153782571009
# 484   675483430902214656
# 523   676588346097852417
# 533   676897532954456065
# 544   677301033169788928
# 606   679877062409191424
# 651   682003177596559360
# 683   683849932751646720
# 701   684880619965411328
# 706   684959798585110529
# 736   687102708889812993
# 803   691483041324204033
# 896   699691744225525762
# 1292  751583847268179968
# 1485  781661882474196992
#
# ...

# %%
archive_clean[archive_clean.rating_numerator == 1][['tweet_id','text','rating_numerator','rating_denominator']]
# Out:
#                tweet_id  \
# 17   666104133288665088
# 93   667549055577362432
# 260  670783437142401025
# 476  675153376133427200
#
#                                                                                                                                              text  \
# 17   Not familiar with this breed. No tail (weird). Only 2 legs. Doesn't bark. Surprisingly quick. Shits eggs. 1/10 https://t.co/Asgdc6kuLX
# 93   Never seen dog like this. Breathes heavy. Tilts head in a pattern. No bark. Shitty at fetch. Not even cordless. 1/10 https://t.co/i9iSGNn3fx
# 260  Flamboyant pup here. Probably poisonous. Won't eat kibble. Doesn't bark. Slow af. Petting doesn't look fun. 1/10 https://t.co/jxukeh2BeO
# 476  What kind of person sends in a picture without a dog in it? 1/10 just because that's a nice table https://t.co/RDXCfk8hK0
#
#      rating_numerator  rating_denominator
# 17   1.0               10
# 93   1.0               10
# 260  1.0               10
# ...

# %%
archive_clean[archive_clean.rating_numerator > 15][['tweet_id','text','rating_numerator','rating_denominator']]
# Out:
#                 tweet_id  \
# 277   670842764863651840
# 501   675853064436391936
# 560   677716515794329600
# 692   684222868335505415
# 693   684225744407494656
# 865   697463031882764288
# 941   704054845121142784
# 1007  709198395643068416
# 1025  710658690886586372
# 1050  713900603437621249
# 1148  731156023742988288
# 1270  749981277374128128
# 1338  758467244762497024
# 1728  820690176645140481
#
#                                                                                                                                                     text  \
# 277   After so many requests... here you go.\n\nGood dogg. 420/10 https://t.co/yfAAo1gdeY
# 501   Here we have an entire platoon of puppers. Total score: 88/80 would pet all at once https://t.co/y93p6FLvVw
# 560   IT'S PUPPERGEDDON. Total of 144/120 ...I think https://t.co/ZanVtAtvIq
# ...

# %% [markdown]
# **Some of the predictions in `p1`, `p2` and `p3` columns start with uppercase letters and others with lowercases.**

# %% [markdown]
# ##### Define
# Change all letters in `p1`, `p2` and `p3` columns to lowercase.

# %% [markdown]
# ##### Code

# %%
predictions_clean.p1 = predictions_clean.p1.str.lower()
predictions_clean.p2 = predictions_clean.p2.str.lower()
predictions_clean.p3 = predictions_clean.p3.str.lower()

# %% [markdown]
# ##### Test

# %%
predictions_clean.sample(10)
# Out:
#                 tweet_id                                          jpg_url  \
# 541   677269281705472000  https://pbs.twimg.com/media/CWYk0WxWoAAEwRt.jpg
# 1861  859924526012018688  https://pbs.twimg.com/media/C-8QypZXcAAekaF.jpg
# 1310  754856583969079297  https://pbs.twimg.com/media/CnnKCKNWgAAcOB8.jpg
# 332   672169685991993344  https://pbs.twimg.com/media/CVQGv-vUwAEUjCj.jpg
# 1646  816816676327063552  https://pbs.twimg.com/media/C1XqbhXXUAElpfI.jpg
# 409   673906403526995968  https://pbs.twimg.com/media/CVoySqoWUAAWb7N.jpg
# 1842  854482394044301312  https://pbs.twimg.com/media/C9u7MtmV0AA741s.jpg
# 269   670823764196741120  https://pbs.twimg.com/media/CU8-puBWwAAR8Xl.jpg
# 463   675006312288268288  https://pbs.twimg.com/media/CV4aqCwWsAIi3OP.jpg
# 1853  857989990357356544  https://pbs.twimg.com/media/C-gxV9ZXkAIBL-S.jpg
#
#      img_num                  p1   p1_conf  p1_dog  \
# 541   1       shetland_sheepdog   0.656616  True
# 1861  1       french_bulldog      0.254587  True
# ...

# %% [markdown]
# **Some column names in the `impage_predictions` table are not descriptive (`p1`, `p1_conf`, `p1_dog`, etc.)**

# %% [markdown]
# ##### Define
# Replace the column names with full words.

# %% [markdown]
# ##### Code

# %%
predictions_clean.head(0)
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %%
predictions_clean.columns = ['tweet_id', 'jpg_url', 'img_num', 'prediction1', 'prediction1_confidence', 'prediction1_is_dog', 'prediction2', 'prediction2_confidence', 'prediction2_is_dog', 'prediction3', 'prediction3_confidence', 'prediction3_is_dog']

# %% [markdown]
# ##### Test

# %%
list(predictions_clean)
# Out:
# ['tweet_id',
#  'jpg_url',
#  'img_num',
#  'prediction1',
#  'prediction1_confidence',
#  'prediction1_is_dog',
#  'prediction2',
#  'prediction2_confidence',
#  'prediction2_is_dog',
#  'prediction3',
#  'prediction3_confidence',
#  'prediction3_is_dog']

# %%
archive_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1993 entries, 0 to 2074
# Data columns (total 13 columns):
# tweet_id                 1993 non-null int64
# in_reply_to_status_id    23 non-null float64
# in_reply_to_user_id      23 non-null float64
# timestamp                1993 non-null datetime64[ns]
# source                   1993 non-null object
# text                     1993 non-null object
# expanded_urls            1993 non-null object
# rating_numerator         1993 non-null float64
# rating_denominator       1993 non-null int64
# name                     1349 non-null object
# dog_stage                306 non-null object
# retweet_count            1992 non-null float64
# favorite_count           1992 non-null float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 218.0+ KB

# %%
predictions_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 1993
# Data columns (total 12 columns):
# tweet_id                  1994 non-null int64
# jpg_url                   1994 non-null object
# img_num                   1994 non-null category
# prediction1               1994 non-null object
# prediction1_confidence    1994 non-null float64
# prediction1_is_dog        1994 non-null bool
# prediction2               1994 non-null object
# prediction2_confidence    1994 non-null float64
# prediction2_is_dog        1994 non-null bool
# prediction3               1994 non-null object
# prediction3_confidence    1994 non-null float64
# prediction3_is_dog        1994 non-null bool
# dtypes: bool(3), category(1), float64(3), int64(1), object(4)
# memory usage: 148.2+ KB

# %% [markdown]
# ## Store

# %%
archive_clean.to_csv('twitter_archive_master.csv')
predictions_clean.to_csv('twitter_predictions.csv')
